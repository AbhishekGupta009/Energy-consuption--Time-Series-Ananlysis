# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekGupta009/Energy-consuption--Time-Series-Ananlysis/blob/main/tsa_energy_consuption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
import pandas as pd
import plotly.express as px

mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['axes.grid'] = False

# %%
df=pd.read_csv("https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/nyc_energy_consumption.csv")
df
# Out:
#                  timeStamp  demand  precip   temp
# 0      2012-01-01 00:00:00  4937.5  0.0000  46.13
# 1      2012-01-01 01:00:00  4752.1  0.0000  45.89
# 2      2012-01-01 02:00:00  4542.6  0.0000  45.04
# 3      2012-01-01 03:00:00  4357.7  0.0000  45.03
# 4      2012-01-01 04:00:00  4275.5  0.0000  42.61
# ...                    ...     ...     ...    ...
# 49200  2017-08-12 02:00:00     NaN  0.0000  70.84
# 49201  2017-08-12 03:00:00     NaN  0.0000  70.57
# 49202  2017-08-12 04:00:00     NaN  0.0000  69.89
# 49203  2017-08-12 05:00:00     NaN  0.0000  68.59
# 49204  2017-08-12 06:00:00     NaN  0.0031  67.33
#
# [49205 rows x 4 columns]

# %%
df['timeStamp']=pd.to_datetime(df['timeStamp'])

# %%
df
# Out:
#                 timeStamp  demand  precip   temp
# 0     2012-01-01 00:00:00  4937.5  0.0000  46.13
# 1     2012-01-01 01:00:00  4752.1  0.0000  45.89
# 2     2012-01-01 02:00:00  4542.6  0.0000  45.04
# 3     2012-01-01 03:00:00  4357.7  0.0000  45.03
# 4     2012-01-01 04:00:00  4275.5  0.0000  42.61
# ...                   ...     ...     ...    ...
# 49200 2017-08-12 02:00:00     NaN  0.0000  70.84
# 49201 2017-08-12 03:00:00     NaN  0.0000  70.57
# 49202 2017-08-12 04:00:00     NaN  0.0000  69.89
# 49203 2017-08-12 05:00:00     NaN  0.0000  68.59
# 49204 2017-08-12 06:00:00     NaN  0.0031  67.33
#
# [49205 rows x 4 columns]

# %%
fig = px.line(df, x='timeStamp', y='demand', hover_data=['temp'], title='NYC Energy Demand')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=2, label="3y", step="year", stepmode="backward"),
            dict(count=3, label="5y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a48636c3-e10b-42b5-94d5-fabc59a46458" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a48636c3-e10b-42b5-94d5-fabc59a46458")) {                    Plotly.newPlot(                        "a48636c3-e10b-42b5-94d5-fabc59a46458",                        [{"customdata":[[46.13],[45.89],[45.04],[45.03],[42.61],[39.02],[38.78],[42.74],[38.9],[44.67],[47.43],[49.49],[50.77],[50.57],[49.94],[49.85],[47.39],[48.83],[48.92],[48.74],[48.98],[49.19],[47.61],[49.72],[49.78],[48.97],[47.12],[44.95],[47.15],[42.04],[39.47],[38.23],[36.83],[37.25],[43.07],[38.25],[39.93],[40.93],[40.84],[39.67],[40.57],[38.23],[38.04],[37.23],[36.32],[35.57],[37.91],[33.57],[33.14],[32.31],[32.04],[31.31],[32.58],[30.4],[29.14],[28.4],[27.57],[26.66],[31.09],[26.43],[25.58],[26.43],[25.75],[26.0],[27.36],[24.23],[23.4],[22.4],[20.64],[19.47],[21.34],[16.47],[15.57],[15.14],[14.37],[13.4],[16.27],[13.47],[13.4],[13.5],[13.73],[14.73],[18.81],[19.27],[21.19],[22.62],[24.93],[25.93],[24.68],[25.59],[26.35],[27.16],[27.4],[27.47],[31.83],[27.23],[27.4],[27.31],[28.07],[28.34],[30.77],[28.4],[29.16],[29.16],[29.49],[30.16],[33.05],[33.25],[36.19],[38.11],[39.02],[39.16],[38.02],[38.23],[38.16],[37.49],[37.98],[37.31],[35.71],[35.92],[34.94],[36.19],[36.57],[36.8],[33.66],[36.35],[36.59],[38.0],[39.17],[38.83],[39.61],[42.12],[45.05],[47.5],[51.1],[51.94],[49.26],[50.15],[50.64],[50.84],[51.01],[50.16],[46.58],[48.56],[49.24],[48.4],[48.3],[46.79],[42.92],[44.81],[44.94],[45.42],[45.42],[48.05],[50.23],[53.49],[56.83],[58.6],[59.66],[61.32],[53.05],[58.81],[57.75],[56.66],[54.41],[53.75],[49.09],[48.01],[46.75],[45.08],[44.38],[43.7],[42.07],[42.89],[41.96],[40.95],[40.85],[42.33],[43.22],[43.18],[44.0],[43.28],[43.1],[43.03],[42.1],[41.17],[39.5],[38.5],[37.23],[36.17],[35.72],[34.05],[33.22],[32.22],[32.07],[31.5],[32.55],[31.98],[31.91],[32.01],[31.74],[33.5],[34.31],[35.0],[37.58],[39.31],[40.14],[39.84],[36.65],[37.43],[37.11],[37.68],[37.85],[38.07],[37.5],[37.47],[37.23],[37.31],[37.14],[36.31],[38.65],[34.96],[34.77],[34.21],[34.3],[35.39],[40.63],[40.35],[43.11],[45.59],[46.57],[46.0],[44.28],[45.66],[44.91],[44.16],[43.91],[43.32],[42.25],[41.07],[40.53],[39.78],[39.42],[38.64],[36.94],[37.48],[37.74],[36.94],[37.73],[39.83],[40.84],[43.48],[45.57],[46.6],[46.35],[45.09],[42.06],[44.19],[44.7],[44.54],[44.03],[43.77],[43.02],[41.38],[41.44],[42.46],[42.44],[43.35],[45.2],[45.26],[45.38],[43.87],[43.51],[43.44],[45.1],[44.37],[43.61],[43.63],[43.62],[43.19],[42.93],[42.0],[42.19],[42.19],[42.39],[42.79],[42.96],[42.69],[42.05],[42.62],[42.45],[44.16],[45.23],[46.65],[48.32],[48.86],[42.22],[41.06],[45.84],[35.69],[34.41],[33.07],[32.42],[32.52],[36.8],[29.33],[29.59],[29.59],[29.33],[29.33],[32.2],[29.33],[28.66],[28.57],[28.57],[28.5],[32.35],[28.33],[28.42],[29.16],[29.23],[29.26],[32.13],[30.19],[31.09],[31.1],[31.43],[32.07],[33.79],[32.16],[32.07],[32.16],[31.34],[30.16],[29.16],[28.16],[27.16],[26.43],[25.24],[23.41],[21.39],[18.4],[17.4],[16.56],[15.83],[15.85],[16.39],[18.35],[20.93],[22.18],[23.43],[23.85],[21.29],[23.4],[22.57],[21.47],[20.57],[20.14],[17.68],[18.4],[17.4],[16.5],[16.41],[16.31],[17.46],[16.22],[16.29],[16.49],[17.35],[18.84],[23.06],[23.85],[27.36],[29.63],[31.9],[33.66],[31.99],[34.26],[34.07],[35.53],[35.74],[36.07],[39.48],[36.07],[36.08],[36.89],[36.24],[36.98],[37.07],[37.07],[37.4],[38.14],[38.14],[39.24],[43.18],[41.24],[41.07],[42.6],[42.66],[42.93],[44.13],[45.57],[46.09],[46.58],[47.97],[49.1],[48.04],[51.2],[51.81],[52.36],[53.81],[50.14],[47.89],[45.04],[42.92],[40.17],[39.16],[38.59],[41.97],[38.1],[37.43],[37.1],[36.61],[34.71],[35.99],[32.17],[30.4],[29.23],[28.14],[27.31],[27.86],[25.14],[24.31],[23.41],[23.07],[22.17],[24 ...

# %%
ny_df=df.set_index('timeStamp')

# %%
ny_df.plot(subplots=True)
# Out:
# array([<Axes: xlabel='timeStamp'>, <Axes: xlabel='timeStamp'>,
#        <Axes: xlabel='timeStamp'>], dtype=object)

# %%
ny_df.resample('D').mean()
# Out:
#                  demand    precip       temp
# timeStamp
# 2012-01-01  4954.833333  0.002487  46.510000
# 2012-01-02  5302.954167  0.000000  40.496667
# 2012-01-03  6095.512500  0.000000  26.672500
# 2012-01-04  6336.266667  0.000000  20.585000
# 2012-01-05  6130.245833  0.000000  33.577500
# ...                 ...       ...        ...
# 2017-08-08  6471.626042  0.000000  71.039167
# 2017-08-09  6811.112167  0.047529  73.852500
# 2017-08-10  5582.297000  0.002033  75.217500
# 2017-08-11          NaN  0.000000  72.767917
# 2017-08-12          NaN  0.000443  69.771429
#
# [2051 rows x 3 columns]

# %%
ny_df.resample('D').mean().plot(subplots=True)
# Out:
# array([<Axes: xlabel='timeStamp'>, <Axes: xlabel='timeStamp'>,
#        <Axes: xlabel='timeStamp'>], dtype=object)

# %%
ny_df_daily=ny_df.resample('D').mean()

# %%
from prophet import Prophet

# %%
ny_df_final=ny_df_daily.reset_index()[['timeStamp','demand','temp']].rename({'timeStamp':'ds','demand':'y','temp':'temp'}, axis='columns')

# %%
ny_df_final
# Out:
#              ds            y       temp
# 0    2012-01-01  4954.833333  46.510000
# 1    2012-01-02  5302.954167  40.496667
# 2    2012-01-03  6095.512500  26.672500
# 3    2012-01-04  6336.266667  20.585000
# 4    2012-01-05  6130.245833  33.577500
# ...         ...          ...        ...
# 2046 2017-08-08  6471.626042  71.039167
# 2047 2017-08-09  6811.112167  73.852500
# 2048 2017-08-10  5582.297000  75.217500
# 2049 2017-08-11          NaN  72.767917
# 2050 2017-08-12          NaN  69.771429
#
# [2051 rows x 3 columns]

# %%
ny_df_final.query('temp != temp')
# Out:
#              ds            y  temp
# 1457 2015-12-28  5510.776333   NaN

# %%
ny_df_final['temp']=ny_df_final['temp'].fillna(method='ffill')

# %%
ny_df_final['month']=ny_df_final['ds'].dt.month

# %%
ny_df_final.head()
# Out:
#           ds            y       temp  month
# 0 2012-01-01  4954.833333  46.510000      1
# 1 2012-01-02  5302.954167  40.496667      1
# 2 2012-01-03  6095.512500  26.672500      1
# 3 2012-01-04  6336.266667  20.585000      1
# 4 2012-01-05  6130.245833  33.577500      1

# %%
fig = px.line(ny_df_final, x='ds', y='y', hover_data=['temp','month'], title='NYC Energy Demand')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=2, label="3y", step="year", stepmode="backward"),
            dict(count=3, label="5y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="867b6cd3-bdef-47d5-920c-68171892af15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("867b6cd3-bdef-47d5-920c-68171892af15")) {                    Plotly.newPlot(                        "867b6cd3-bdef-47d5-920c-68171892af15",                        [{"customdata":[[46.51,1.0],[40.49666666666666,1.0],[26.6725,1.0],[20.585,1.0],[33.5775,1.0],[43.40083333333333,1.0],[51.49791666666667,1.0],[41.467083333333335,1.0],[35.36,1.0],[40.50333333333334,1.0],[41.69375,1.0],[43.33375,1.0],[37.627916666666664,1.0],[30.33583333333333,1.0],[20.763333333333332,1.0],[25.914166666666663,1.0],[41.900416666666665,1.0],[38.50208333333333,1.0],[28.640833333333333,1.0],[30.347083333333334,1.0],[26.077083333333334,1.0],[26.61583333333333,1.0],[41.49333333333333,1.0],[47.55458333333333,1.0],[40.229166666666664,1.0],[36.802083333333336,1.0],[48.96,1.0],[42.54875,1.0],[39.20083333333333,1.0],[37.12083333333333,1.0],[46.67041666666666,1.0],[54.01083333333333,2.0],[42.4575,2.0],[36.819583333333334,2.0],[41.18083333333333,2.0],[35.15,2.0],[41.06041666666667,2.0],[42.87291666666667,2.0],[34.14791666666667,2.0],[37.3675,2.0],[39.372499999999995,2.0],[35.7825,2.0],[27.10166666666667,2.0],[35.07125,2.0],[41.08833333333333,2.0],[42.235416666666666,2.0],[40.235416666666666,2.0],[45.159166666666664,2.0],[40.88708333333333,2.0],[39.00083333333333,2.0],[37.224583333333335,2.0],[39.60541666666666,2.0],[48.34,2.0],[50.23583333333334,2.0],[41.16166666666667,2.0],[40.65833333333333,2.0],[36.33208333333334,2.0],[44.89541666666667,2.0],[43.97541666666667,2.0],[39.562916666666666,2.0],[39.53541666666667,3.0],[37.518750000000004,3.0],[48.26625000000001,3.0],[41.10583333333333,3.0],[36.09666666666667,3.0],[33.74791666666667,3.0],[47.94,3.0],[59.43166666666667,3.0],[45.33166666666667,3.0],[36.0,3.0],[45.64625,3.0],[55.36541666666667,3.0],[61.79458333333333,3.0],[62.89083333333334,3.0],[46.28875,3.0],[45.031666666666666,3.0],[50.541666666666664,3.0],[50.88791666666666,3.0],[60.4,3.0],[61.35208333333333,3.0],[59.19166666666666,3.0],[62.63083333333333,3.0],[64.81041666666667,3.0],[56.88666666666666,3.0],[47.60583333333333,3.0],[47.632083333333334,3.0],[40.49583333333333,3.0],[53.862500000000004,3.0],[52.555416666666666,3.0],[46.11541666666667,3.0],[40.885416666666664,3.0],[45.92208333333334,4.0],[47.77125,4.0],[51.68541666666667,4.0],[58.137499999999996,4.0],[48.73374999999999,4.0],[46.95583333333334,4.0],[50.17625,4.0],[55.07333333333333,4.0],[55.61416666666667,4.0],[52.55375,4.0],[47.475833333333334,4.0],[50.446666666666665,4.0],[53.32958333333334,4.0],[60.560833333333335,4.0],[67.62208333333334,4.0],[72.99208333333333,4.0],[71.81708333333334,4.0],[55.60458333333333,4.0],[55.812916666666666,4.0],[59.63125,4.0],[61.46458333333334,4.0],[50.39166666666667,4.0],[50.12958333333333,4.0],[49.76791666666667,4.0],[53.106249999999996,4.0],[52.47833333333333,4.0],[49.285,4.0],[48.24583333333334,4.0],[53.11291666666667,4.0],[51.77875,4.0],[57.98333333333333,5.0],[51.673750000000005,5.0],[53.74,5.0],[60.7125,5.0],[57.54666666666666,5.0],[57.48666666666667,5.0],[56.98,5.0],[58.60458333333333,5.0],[63.28375,5.0],[58.10791666666666,5.0],[58.86958333333334,5.0],[65.35708333333334,5.0],[70.86416666666666,5.0],[66.06083333333333,5.0],[62.65833333333333,5.0],[67.94583333333334,5.0],[63.550000000000004,5.0],[61.187083333333334,5.0],[64.0225,5.0],[66.10458333333334,5.0],[60.04708333333334,5.0],[64.11333333333333,5.0],[67.58041666666666,5.0],[64.16416666666667,5.0],[64.80166666666666,5.0],[72.55916666666667,5.0],[72.53166666666667,5.0],[77.0475,5.0],[80.24249999999999,5.0],[71.72583333333334,5.0],[72.27791666666667,5.0],[65.49583333333334,6.0],[67.325,6.0],[64.95041666666667,6.0],[58.98083333333333,6.0],[57 ...

# %%
ny_df_final[['month','temp']].groupby('month').agg({'temp':{'max','min','mean'}})
# Out:
#             temp
#              min        max       mean
# month
# 1       9.507917  55.420455  33.432140
# 2       9.015000  59.360000  34.517758
# 3      20.291667  67.878333  41.419884
# 4      33.045833  72.992083  52.600204
# 5      48.090833  82.576250  62.543994
# 6      52.405833  86.916667  71.334418
# 7      66.417083  89.606667  77.595627
# 8      68.042083  87.426250  75.525947
# 9      57.274583  84.448750  69.550306
# 10     42.106250  74.277500  58.642895
# 11     27.172500  67.606250  47.225638
# 12     22.429583  64.735000  41.520068

# %%
ny_df_final[['y','temp']].corr()
# Out:
#              y      temp
# y     1.000000  0.560888
# temp  0.560888  1.000000

# %%
ny_df_final.query('temp > 80')[['y','temp']].corr()
# Out:
#              y      temp
# y     1.000000  0.552918
# temp  0.552918  1.000000

# %%
ny_df_final.query('temp <= 80')[['y','temp']].corr()
# Out:
#              y      temp
# y     1.000000  0.470562
# temp  0.470562  1.000000

# %%
def summer_temp(temp):
  if temp > 80:
    return 1
  else:
    return 0

# %%
ny_df_final['summer_temp']=ny_df_final['temp'].apply(summer_temp)

# %%
ny_df_final['month_bins']=pd.cut(ny_df_final['month'],bins=3, labels=False)

# %%
ny_df_final
# Out:
#              ds            y       temp  month  summer_temp  month_bins
# 0    2012-01-01  4954.833333  46.510000      1            0           0
# 1    2012-01-02  5302.954167  40.496667      1            0           0
# 2    2012-01-03  6095.512500  26.672500      1            0           0
# 3    2012-01-04  6336.266667  20.585000      1            0           0
# 4    2012-01-05  6130.245833  33.577500      1            0           0
# ...         ...          ...        ...    ...          ...         ...
# 2046 2017-08-08  6471.626042  71.039167      8            0           1
# 2047 2017-08-09  6811.112167  73.852500      8            0           1
# 2048 2017-08-10  5582.297000  75.217500      8            0           1
# 2049 2017-08-11          NaN  72.767917      8            0           1
# 2050 2017-08-12          NaN  69.771429      8            0           1
#
# [2051 rows x 6 columns]

# %%
train=ny_df_final[(ny_df_final['ds'] >= '2012-01-01') & (ny_df_final['ds'] <= '2017-04-30')]
test=ny_df_final[(ny_df_final['ds'] > '2017-04-30')]

# %%
train.shape
# Out:
# (1947, 6)

# %%
test.shape
# Out:
# (104, 6)

# %%
test
# Out:
#              ds            y       temp  month  summer_temp  month_bins
# 1947 2017-05-01  5417.231583  60.300833      5            0           1
# 1948 2017-05-02  5697.950042  67.537917      5            0           1
# 1949 2017-05-03  5354.628500  59.413333      5            0           1
# 1950 2017-05-04  5235.704833  54.877083      5            0           1
# 1951 2017-05-05  5358.639500  55.720833      5            0           1
# ...         ...          ...        ...    ...          ...         ...
# 2046 2017-08-08  6471.626042  71.039167      8            0           1
# 2047 2017-08-09  6811.112167  73.852500      8            0           1
# 2048 2017-08-10  5582.297000  75.217500      8            0           1
# 2049 2017-08-11          NaN  72.767917      8            0           1
# 2050 2017-08-12          NaN  69.771429      8            0           1
#
# [104 rows x 6 columns]

# %%
m = Prophet(interval_width=0.95,yearly_seasonality=True)

# %%
m.add_regressor('summer_temp',standardize=False)
m.add_regressor('month_bins',standardize=False,mode='multiplicative')

# %%
m.fit(train)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7fz5eek2/7z05it50.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp7fz5eek2/m0w06und.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46874', 'data', 'file=/tmp/tmp7fz5eek2/7z05it50.json', 'init=/tmp/tmp7fz5eek2/m0w06und.json', 'output', 'file=/tmp/tmp7fz5eek2/prophet_modelyg2i46tu/prophet_model-20230508200955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:09:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:09:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
m.params
# Out:
# OrderedDict([('lp__', array([[5340.12]])),
#              ('k', array([[0.162932]])),
#              ('m', array([[0.588011]])),
#              ('delta',
#               array([[-7.77904e-08, -1.09243e-03, -2.02140e-01, -2.32348e-08,
#                       -8.37727e-08,  1.23223e-02,  1.16328e-02,  9.40565e-03,
#                        1.35367e-03,  2.05016e-08,  3.40767e-07, -5.55275e-02,
#                       -2.35714e-07,  7.70930e-08,  1.55860e-01,  1.46828e-07,
#                       -2.20277e-07, -1.02506e-01, -4.32700e-02, -1.28267e-07,
#                       -9.44383e-09, -9.75008e-08,  3.65785e-02,  2.62860e-02,
#                        3.04505e-08]])),
#              ('sigma_obs', array([[0.038781]])),
#              ('beta',
#               array([[-0.0356543 , -0.0591281 ,  0.049373  ,  0.0401483 , -0.0094908 ,
#                       -0.00176262, -0.00782968, -0.00252721,  0.00339328, -0.0058574 ,
#                        0.0014147 ,  0.00306482, -0.0052757 , -0.00380534,  0.00335172,
#                       -0.0027667 ,  0.00072147,  0.00144131, -0.00132655, -0.00031813,
#                       -0.0271961 ,  0.0241491 ,  0.0202734 ,  0.00152722, -0.00497178,
#                       -0.00518704,  0.133952  , -0.00953799]])),
#              ('trend',
#               array([[0.588011, 0.588095, 0.588178, ..., 0.596275, 0.596281, 0.596287]]))])

# %%
future = m.make_future_dataframe(periods=104)
future.tail()
# Out:
#              ds
# 2046 2017-08-08
# 2047 2017-08-09
# 2048 2017-08-10
# 2049 2017-08-11
# 2050 2017-08-12

# %%
future
# Out:
#              ds
# 0    2012-01-01
# 1    2012-01-02
# 2    2012-01-03
# 3    2012-01-04
# 4    2012-01-05
# ...         ...
# 2046 2017-08-08
# 2047 2017-08-09
# 2048 2017-08-10
# 2049 2017-08-11
# 2050 2017-08-12
#
# [2051 rows x 1 columns]
